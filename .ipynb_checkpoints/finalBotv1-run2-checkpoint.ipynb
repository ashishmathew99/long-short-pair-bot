# %%
# main issues:
# fix stop loss/ max wdd
# partial fills
# multiple pairs at one time
# issues with multiple pairs with similar legs, memory management
# trailing profit take
#     1) take 
#     1) sell bad leg and use winning leg to run    

# innovations
# increase volume
# make new models whcih are scalping or momentum models

# kalmans filters
# copulas
# nonlinear distributions
# extreme value theory
# last three are similar
# pair trading with multiple exchanges

# limit orders
# max win drawdown
# advanced risk mitigation 
# if long and first priotirty to get rid off -> sell at market
# if short and first prioity to get rid off -> sell at market
# pair splitting

# ---

# need to fix
# order sizes mgiht be too small so need to take into consideration leg prices and sizes

# %%
# imports and requirements
import json
import requests
import pandas as pd
import numpy as np
import ccxt
import time
import datetime as dt
import matplotlib.pyplot as plt

from binance.client import Client
from binance.enums import *

# %%
# init client
apiKey = 'Xo3vFSsM4XoYge93eqCA3gxmHQTN3rWqOs1LtUsHK9UQDKFcvRp1hMRmIiFIolsh'
apiSecret = ';)'

# python-binance init
client = Client(apiKey, apiSecret)
# ccxt init
exchange = ccxt.binance({
    'apiKey': 'Xo3vFSsM4XoYge93eqCA3gxmHQTN3rWqOs1LtUsHK9UQDKFcvRp1hMRmIiFIolsh',
    'secret': ';)',
    'enableRateLimit': True,  # as required by the Manual
    'options': { 'defaultType': 'future' }
})

# %%
# inputs
leg1 = input("Input leg 1: ")
leg2 = input("Input leg 2: ")
timeframe = input("Input timeframe/ interval: ")
emalen = input("Input Lookback/ EMA length: ")
legval = float(input("Leg Value: "))

# convert legs
if leg1 == 'ONTUSDT':
    newLeg1 = 'ONT/USDT'
elif leg1 == 'ETHUSDT':
    newLeg1 = 'ETH/USDT'
    
if leg2 == 'QTUMUSDT':
    newLeg2 = 'QTUM/USDT'
elif leg2 == 'XTZUSDT':
    newLeg2 = 'XTZ/USDT'

print("New leg 1:", format(newLeg1))
print("New leg 2:", format(newLeg2))
# Out:
# Input leg 1: ETHUSDT
# Input leg 2: XTZUSDT
# Input timeframe/ interval: 5m
# Input Lookback/ EMA length: 20
# Leg Value: 5
# New leg 1: ETH/USDT
# New leg 2: XTZ/USDT

# %%
# create dataframe
def dataframe(symbol, interval, timeframe):
    rootUrl = 'https://api.binance.com/api/v1/klines'
    url = rootUrl + '?symbol=' + symbol + '&interval=' + interval + '&limit=' + timeframe
    data = json.loads(requests.get(url).text)
    df = pd.DataFrame(data)
    df.columns = ['open_time',
                 'o', 'h', 'l', 'c', 'v',
                 'closeTime', 'qav', 'numTrades',
                 'takerBase_Bol', 'takerQuoteVol', 'ignore']
    df.index = [dt.datetime.fromtimestamp(x/1000.0) for x in df.closeTime]
    return df

dataframe(leg1, timeframe, emalen)
# Out:
#                              open_time             o             h  \
# 2020-06-04 13:44:59.999  1591242000000  245.62000000  245.66000000
# 2020-06-04 13:49:59.999  1591242300000  245.65000000  246.40000000
# 2020-06-04 13:54:59.999  1591242600000  245.79000000  245.87000000
# 2020-06-04 13:59:59.999  1591242900000  245.52000000  245.74000000
# 2020-06-04 14:04:59.999  1591243200000  245.34000000  245.45000000
# 2020-06-04 15:14:59.999    80.283679
# 2020-06-04 15:19:59.999    80.386931
# 2020-06-04 15:24:59.999    80.376167
# 2020-06-04 15:29:59.999    80.372295
# 2020-06-04 15:34:59.999    80.323282
# 2020-06-04 15:39:59.999    80.481027
# 2020-06-04 15:44:59.999    80.299128
# 2020-06-04 15:49:59.999    80.470019
# 2020-06-04 15:54:59.999    80.500729
# Name: c, dtype: float64

# %%
priceLeg1 = dataframe(leg1,timeframe,emalen)['c'].astype('float')[-1].tolist()
amountLeg1 = round(legval/priceLeg1,3)
print ("Amount of leg1: {}". format(amountLeg1))
# Out:
# Amount of leg1: 0.021

# %%
# prints price chart
priceChart().plot(figsize=(16,9))

# %%
# current zscore
def currZscore():
    currStd = priceChart().std()
    currMean = priceChart().mean()
    a = priceChart().tolist()
    x = a[-1:]
    
    y = [float(i) for i in x]

    zscore = (y[0] - currMean)/currStd
    return round(zscore,5)

print("Current Z-Score = %s" % currZscore())
# Out:
# Current Z-Score = 0.93615

# %%
# short buy and long exit
def shortSide(leg1, leg2, legval):
    
    print("Short side function: ...")
    # amount for each leg
    priceLeg1 = dataframe(leg1,timeframe,emalen)['c'].astype('float')[-1].tolist()
    amountLeg1 = round(legval/priceLeg1,3)
    print ("Amount of leg1: {}". format(amountLeg1))
    priceLeg2 = dataframe(leg2,timeframe,emalen)['c'].astype('float')[-1].tolist()
    amountLeg2 = round(legval/priceLeg2,1)
    print ("Amount of leg2: {}". format(amountLeg2))
    print("-----")

    # short leg1    
    order1 = exchange.createOrder(newLeg1, 'market', 'sell', amountLeg1)
    print("Shorted leg 1")
    print(order1)
    # long leg 2
    order2 = exchange.createOrder(newLeg2, 'market', 'buy', amountLeg2)
    print("Longed leg 2")
    print(order2)
    
    inPos = True
    print ("inPos status before exit checks: {}". format(inPos))
    print("-----")

    
    # exit conds
    while (inPos == True):
        exZscore = currZscore()
            
        if exZscore <= 0:
            print ("Exiting! Current ZScore: {}". format(exZscore))
            order3 = exchange.createOrder (newLeg1, 'market', 'buy', amountLeg1)
            print("Long/ exited leg 1")
            print(order3)
            order4 = exchange.createOrder (newLeg2, 'market', 'sell', amountLeg2)
            print("Short/ exited leg 2")
            print(order4)
            print("-----")
            inPos = False
            print ("inPos status after exiting: {}". format(inPos))
        else:
            print ("Current ZScore: {}". format(exZscore))
            print("Sleeping 5 secs...")
            print("-----")
            time.sleep(5)
    
    "Calling entryConds for new buy session..."
    entryConds()
# Out:
# Short side function: ...
# Amount of leg1: 0.021
# Amount of leg2: 1.7
# -----
# Shorted leg 1
# {'info': {'orderId': 1953916558, 'symbol': 'ETHUSDT', 'status': 'NEW', 'clientOrderId': '30tmPoZqJ95WoDNXj750vP', 'price': '0', 'avgPrice': '0.00000', 'origQty': '0.021', 'executedQty': '0', 'cumQty': '0', 'cumQuote': '0', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'BOTH', 'stopPrice': '0', 'workingType': 'CONTRACT_PRICE', 'origType': 'MARKET', 'updateTime': 1591250318828}, 'id': '1953916558', 'clientOrderId': '30tmPoZqJ95WoDNXj750vP', 'timestamp': None, 'datetime': None, 'lastTradeTimestamp': None, 'symbol': 'ETH/USDT', 'type': 'market', 'side': 'sell', 'price': 0.0, 'amount': 0.021, 'cost': 0.0, 'average': None, 'filled': 0.0, 'remaining': 0.021, 'status': 'open', 'fee': None, 'trades': None}
# Longed leg 2
# {'info': {'orderId': 228684656, 'symbol': 'XTZUSDT', 'status': 'NEW', 'clientOrderId': 'Qc5GfKDQljMNaa9B8Bw3le', 'price': '0', 'avgPrice': '0.0000', 'origQty': '1.7', 'executedQty': '0', 'cumQty': '0', 'cumQuote': '0', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'BOTH', 'stopPrice': '0', 'workingType': 'CONTRACT_PRICE', 'origType': 'MARKET', 'updateTime': 1591250319331}, 'id': '228684656', 'clientOrderId': 'Qc5GfKDQljMNaa9B8Bw3le', 'timestamp': None, 'datetime': None, 'lastTradeTimestamp': None, 'symbol': 'XTZ/USDT', 'type': 'market', 'side': 'buy', 'price': 0.0, 'amount': 1.7, 'cost': 0.0, 'average': None, 'filled': 0.0, 'remaining': 1.7, 'status': 'open', 'fee': None, 'trades': None}

# %%
# long buy
def longSide(leg1, leg2, legval):
    
    print("Long side function: ...")
    # amount for each leg
    priceLeg1 = dataframe(leg1,timeframe,emalen)['c'].astype('float')[-1].tolist()
    amountLeg1 = round(legval/priceLeg1,3)
    print ("Amount of leg1: {}". format(amountLeg1))
    
    priceLeg2 = dataframe(leg2,timeframe,emalen)['c'].astype('float')[-1].tolist()
    amountLeg2 = round(legval/priceLeg2,1)
    print ("Amount of leg2: {}". format(amountLeg2))
    print("-----")
        
    # long leg1
    order1 = exchange.createOrder(newLeg1, 'market', 'buy', amountLeg1)
    print("Longed leg 1")
    print(order1)
    # short leg 2
    order2 = exchange.createOrder(newLeg2, 'market', 'sell', amountLeg2)
    print("Shorted leg 2")
    print(order2)
    print("-----")
    
    inPos = True
    print ("inPos status: {}". format(inPos))
    
    while (inPos == True):
        exZscore = currZscore()
            
        if exZscore >= 0:
            print ("Exiting! Current ZScore: {}". format(exZscore))
            order3 = exchange.createOrder (newLeg1, 'market', 'sell', amountLeg1)
            print("Short/ exited leg 1")
            print(order3)
            order4 = exchange.createOrder (newLeg2, 'market', 'buy', amountLeg2)
            print("Long/ exited leg 2")
            print(order4)
            print("-----")
            inPos = False
            print ("inPos status after exiting: {}". format(inPos))
        else:
            print ("Current ZScore: {}". format(exZscore))
            print("Sleeping 5 secs...")
            print("-----")
            time.sleep(5)
    
    "Calling entryConds"
    entryConds()

# %%
# entry conds
def entryConds():
    entered = False
    print ("Entry status at start of loop: {}". format(entered))
    print("-----")
    
    while entered == False:
        enZscore = currZscore()
        print ("Entry Zscore: {}". format(enZscore))

        if enZscore >= 2:
            print("Entering short side")
            print("-----")
            entered = True
            shortSide(leg1,leg2,legval)
        elif enZscore <= -2:
            print("Entering long side")
            print("-----")
            entered = True
            longSide(leg1,leg2,legval)
        else:
            print("No entry. Sleeping 5 secs...")
            print("-----")
            time.sleep(5)

entryConds()
# Out:
# Entry status at start of loop: False
# -----
# Entry Zscore: 1.11824
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.21165
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.79451
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.89073
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.83404
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.70362
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.44723
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.69214
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.72819
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.6604
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.62234
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.54727
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.5662
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.64866
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.45548
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.44845
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.52824
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.52846
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.76945
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.74744
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.49254
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.49754
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.72238
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.34483
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.47461
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.46337
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.44387
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.6083
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.54133
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.49454
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.31527
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.46785
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.52846
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.20595
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.31198
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.29376
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.27134
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.27134
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.18893
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.26735
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.20562
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.27678
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.52368
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.46984
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.45623
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.33101
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.30775
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.38217
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.31234
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.33559
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.27216
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: -0.02882
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.09662
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.42853
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.15061
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.62872
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.68264
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.65271
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.68507
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.4696
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.62916
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.65566
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.55108
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.58014
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: -0.10402
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.29476
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: -0.21184
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: -0.32282
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: -0.47046
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: -0.53666
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: -0.81623
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: -0.39162
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: -0.60674
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: -0.66886
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: -0.06411
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: -0.4798
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: -0.12304
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: -0.01387
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: -0.06497
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.24952
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.15863
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.15855
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.44629
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.38997
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.37037
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.34438
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.5388
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.68596
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.42452
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.12154
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.57794
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.79433
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 1.52952
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 2.01198
# Entering short side
# -----
# Short side function: ...
# Amount of leg1: 0.0
# Amount of leg2: 1.7
# -----
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\ccxt\base\exchange.py in fetch(self, url, method, headers, body)
#     565             self.logger.debug("%s %s, Response: %s %s %s", method, url, http_status_code, headers, http_response)
# --> 566             response.raise_for_status()
#     567
#
# ~\anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 400 Client Error: Bad Request for url: https://fapi.binance.com/fapi/v1/order
#
# During handling of the above exception, another exception occurred:
#
# ExchangeError                             Traceback (most recent call last)
# <ipython-input-11-145f3ad60c0b> in <module>
#      24             time.sleep(5)
#      25
# ---> 26 entryConds()
#
# <ipython-input-11-145f3ad60c0b> in entryConds()
#      13             print("-----")
#      14             entered = True
# ---> 15             shortSide(leg1,leg2,legval)
#      16         elif enZscore <= -2:
#      17             print("Entering long side")
#
# <ipython-input-8-f8111fd2e85c> in shortSide(leg1, leg2, legval)
#      15
#      16     # short leg1
# ---> 17     order1 = exchange.createOrder(newLeg1, 'market', 'sell', amountLeg1)
#      18     print("Shorted leg 1")
#      19     print(order1)
#
# ~\anaconda3\lib\site-packages\ccxt\binance.py in create_order(self, symbol, type, side, amount, price, params)
#    1198                 params = self.omit(params, 'stopPrice')
#    1199                 request['stopPrice'] = self.price_to_precision(symbol, stopPrice)
# -> 1200         response = getattr(self, method)(self.extend(request, params))
#    1201         return self.parse_order(response, market)
#    1202
#
# ~\anaconda3\lib\site-packages\ccxt\base\exchange.py in inner(_self, params)
#     448                             if params is not None:
#     449                                 inner_kwargs['params'] = params
# --> 450                             return entry(_self, **inner_kwargs)
#     451                         return inner
#     452                     to_bind = partialer()
#
# ~\anaconda3\lib\site-packages\ccxt\binance.py in request(self, path, api, method, params, headers, body)
#    1929
#    1930     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
# -> 1931         response = self.fetch2(path, api, method, params, headers, body)
#    1932         # a workaround for {"code":-2015,"msg":"Invalid API-key, IP, or permissions for action."}
#    1933         if (api == 'private') or (api == 'wapi'):
#
# ~\anaconda3\lib\site-packages\ccxt\base\exchange.py in fetch2(self, path, api, method, params, headers, body)
#     467         self.lastRestRequestTimestamp = self.milliseconds()
#     468         request = self.sign(path, api, method, params, headers, body)
# --> 469         return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#     470
#     471     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
#
# ~\anaconda3\lib\site-packages\ccxt\base\exchange.py in fetch(self, url, method, headers, body)
#     576
#     577         except HTTPError as e:
# --> 578             self.handle_errors(http_status_code, http_status_text, url, method, headers, http_response, json_response, request_headers, request_body)
#     579             self.handle_rest_errors(http_status_code, http_status_text, http_response, url, method)
#     580             raise ExchangeError(method + ' ' + url)
#
# ~\anaconda3\lib\site-packages\ccxt\binance.py in handle_errors(self, code, reason, url, method, headers, body, response, requestHeaders, requestBody)
#    1924             feedback = self.id + ' ' + body
#    1925             self.throw_exactly_matched_exception(self.exceptions, error, feedback)
# -> 1926             raise ExchangeError(feedback)
#    1927         if not success:
#    1928             raise ExchangeError(self.id + ' ' + body)
#
# ExchangeError: binance {"code":-4003,"msg":"Quantity less than zero."}
