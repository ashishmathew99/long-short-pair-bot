# %%
# main issues:
# fix stop loss/ max wdd
# partial fills
# multiple pairs at one time
# issues with multiple pairs with similar legs, memory management
# trailing profit take
#     1) take 
#     1) sell bad leg and use winning leg to run    

# innovations
# increase volume
# make new models whcih are scalping or momentum models

# kalmans filters
# copulas
# nonlinear distributions
# extreme value theory
# last three are similar
# pair trading with multiple exchanges

# limit orders
# max win drawdown
# advanced risk mitigation 
# if long and first priotirty to get rid off -> sell at market
# if short and first prioity to get rid off -> sell at market
# pair splitting

# %%
# imports and requirements
import json
import requests
import pandas as pd
import numpy as np
import ccxt
import time
import datetime as dt
import matplotlib.pyplot as plt

from binance.client import Client
from binance.enums import *

# %%
# init client
apiKey = 'Xo3vFSsM4XoYge93eqCA3gxmHQTN3rWqOs1LtUsHK9UQDKFcvRp1hMRmIiFIolsh'
apiSecret = ';)'

# python-binance init
client = Client(apiKey, apiSecret)
# ccxt init
exchange = ccxt.binance({
    'apiKey': 'Xo3vFSsM4XoYge93eqCA3gxmHQTN3rWqOs1LtUsHK9UQDKFcvRp1hMRmIiFIolsh',
    'secret': ';)',
    'enableRateLimit': True,  # as required by the Manual
    'options': { 'defaultType': 'future' }
})

# %%
# inputs
leg1 = input("Input leg 1: ")
leg2 = input("Input leg 2: ")
timeframe = input("Input timeframe/ interval: ")
emalen = input("Input Lookback/ EMA length: ")
legval = float(input("Leg Value: "))

# convert legs
if leg1 == 'ONTUSDT':
    newLeg1 = 'ONT/USDT'
elif leg1 == 'ETHUSDT':
    newLeg1 = 'ETH/USDT'
elif leg1 == 'BCHUSDT':
    newLeg1 = 'BCH/USDT'
    
if leg2 == 'QTUMUSDT':
    newLeg2 = 'QTUM/USDT'
elif leg2 == 'XTZUSDT':
    newLeg2 = 'XTZ/USDT'
elif leg2 == 'LTCUSDT':
    newLeg2 = 'LTC/USDT'

print("New leg 1:", format(newLeg1))
print("New leg 2:", format(newLeg2))
# Out:
# Input leg 1: BCHUSDT
# Input leg 2: LTCUSDT
# Input timeframe/ interval: 15m
# Input Lookback/ EMA length: 20
# Leg Value: 5
# New leg 1: BCH/USDT
# New leg 2: LTC/USDT

# %%
# create dataframe
def dataframe(symbol, interval, timeframe):
    rootUrl = 'https://api.binance.com/api/v1/klines'
    url = rootUrl + '?symbol=' + symbol + '&interval=' + interval + '&limit=' + timeframe
    data = json.loads(requests.get(url).text)
    df = pd.DataFrame(data)
    df.columns = ['open_time',
                 'o', 'h', 'l', 'c', 'v',
                 'closeTime', 'qav', 'numTrades',
                 'takerBase_Bol', 'takerQuoteVol', 'ignore']
    df.index = [dt.datetime.fromtimestamp(x/1000.0) for x in df.closeTime]
    return df

dataframe(leg1, timeframe, emalen)
# Out:
#                              open_time             o             h  \
# 2020-06-04 10:44:59.999  1591230600000  252.38000000  252.68000000
# 2020-06-04 10:59:59.999  1591231500000  252.29000000  252.88000000
    return hedgeChart

# prints price chart
priceChart().plot(figsize=(16,9))

# %%
# current zscore
def currZscore():
    currStd = priceChart().std()
    currMean = priceChart().mean()
    a = priceChart().tolist()
    x = a[-1:]
    
    y = [float(i) for i in x]

    zscore = (y[0] - currMean)/currStd
    return round(zscore,5)

print("Current Z-Score = %s" % currZscore())
# Out:
# Current Z-Score = 0.54105

# %%
# short buy and long exit
def shortSide(leg1, leg2, legval):
    
    print("Short side function: ...")
    # amount for each leg
    priceLeg1 = dataframe(leg1,timeframe,emalen)['c'].astype('float')[-1].tolist()
    amountLeg1 = round(legval/priceLeg1,3)
    print ("Amount of leg1: {}". format(amountLeg1))
    
    priceLeg2 = dataframe(leg2,timeframe,emalen)['c'].astype('float')[-1].tolist()
    amountLeg2 = round(legval/priceLeg2,1)
    print ("Amount of leg2: {}". format(amountLeg2))
    print("-----")


    # short leg1    
    order1 = exchange.createOrder(newLeg1, 'market', 'sell', amountLeg1)
    print("Shorted leg 1")
    print(order1)
    # long leg 2
    order2 = exchange.createOrder(newLeg2, 'market', 'buy', amountLeg2)
    print("Longed leg 2")
    print(order2)
    
    inPos = True
    print ("inPos status before exit checks: {}". format(inPos))
    print("-----")

    
    # exit conds
    while (inPos == True):
        exZscore = currZscore()
            
        if exZscore <= 0:
            print ("Exiting! Current ZScore: {}". format(exZscore))
            order3 = exchange.createOrder (newLeg1, 'market', 'buy', amountLeg1)
            print("Long/ exited leg 1")
            print(order3)
            order4 = exchange.createOrder (newLeg2, 'market', 'sell', amountLeg2)
            print("Short/ exited leg 2")
            print(order4)
            print("-----")
            inPos = False
            print ("inPos status after exiting: {}". format(inPos))
        else:
            print ("Current ZScore: {}". format(exZscore))
            print("Sleeping 5 secs...")
            print("-----")
            time.sleep(5)
    
    "Calling entryConds for new buy session..."
    entryConds()

# %%
# long buy
def longSide(leg1, leg2, legval):
    
    print("Long side function: ...")
    # amount for each leg
    priceLeg1 = dataframe(leg1,timeframe,emalen)['c'].astype('float')[-1].tolist()
    amountLeg1 = round(legval/priceLeg1,3)
    print ("Amount of leg1: {}". format(amountLeg1))
    
    priceLeg2 = dataframe(leg2,timeframe,emalen)['c'].astype('float')[-1].tolist()
    amountLeg2 = round(legval/priceLeg2,1)
    print ("Amount of leg2: {}". format(amountLeg2))
    print("-----")
        
    # long leg1
    order1 = exchange.createOrder(newLeg1, 'market', 'buy', amountLeg1)
    print("Longed leg 1")
    print(order1)
    # short leg 2
    order2 = exchange.createOrder(newLeg2, 'market', 'sell', amountLeg2)
    print("Shorted leg 2")
    print(order2)
    print("-----")
    
    inPos = True
    print ("inPos status: {}". format(inPos))
    
    while (inPos == True):
        exZscore = currZscore()
            
        if exZscore >= 0:
            print ("Exiting! Current ZScore: {}". format(exZscore))
            order3 = exchange.createOrder (newLeg1, 'market', 'sell', amountLeg1)
            print("Short/ exited leg 1")
            print(order3)
            order4 = exchange.createOrder (newLeg2, 'market', 'buy', amountLeg2)
            print("Long/ exited leg 2")
            print(order4)
            print("-----")
            inPos = False
            print ("inPos status after exiting: {}". format(inPos))
        else:
            print ("Current ZScore: {}". format(exZscore))
            print("Sleeping 5 secs...")
            print("-----")
            time.sleep(5)
    
    "Calling entryConds"
    entryConds()

# %%
# entry conds
def entryConds():
    entered = False
    print ("Entry status at start of loop: {}". format(entered))
    print("-----")
    
    while entered == False:
        enZscore = currZscore()
        print ("Entry Zscore: {}". format(enZscore))

        if enZscore >= 2:
            print("Entering short side")
            print("-----")
            entered = True
            shortSide(leg1,leg2,legval)
        elif enZscore <= -2:
            print("Entering long side")
            print("-----")
            entered = True
            longSide(leg1,leg2,legval)
        else:
            print("No entry. Sleeping 5 secs...")
            print("-----")
            time.sleep(5)

entryConds()
# Out:
# Entry status at start of loop: False
# -----
# Entry Zscore: 0.56232
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.618
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.52207
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.61545
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.58401
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.48146
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.60917
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.63682
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.65476
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.66949
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.59286
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.59286
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.55879
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.55879
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.61428
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.54616
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.55879
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.62778
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.57981
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.61171
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.64818
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.68198
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.66325
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.66069
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.69444
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.73427
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.61769
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.6962
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.7131
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.66069
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.69444
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.71565
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.68198
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.68198
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.66325
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.66325
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.7794
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.69954
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.7305
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.73211
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.73316
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.65394
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.68792
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.61917
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.5827
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.69782
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.67578
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.60524
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.65304
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.59405
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.55755
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.57005
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.57313
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.61776
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.72154
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.72154
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.55368
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.60046
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.66808
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.68056
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.70144
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.629
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.66694
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.60482
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.59778
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.55999
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.57283
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.59149
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.61873
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.61545
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.58401
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.618
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.58334
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.62173
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.6733
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.68361
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.68311
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.74598
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.74267
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.74625
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.75139
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.74252
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.70434
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.73792
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.66439
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.67079
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.73792
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.69812
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.69812
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.69812
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.70434
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.73894
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.66857
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.71
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.70913
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.66553
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.65304
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.64678
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.68424
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.72507
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.67801
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.67801
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.71167
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.67178
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.69924
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.60153
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.618
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.63682
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.63682
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.60662
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.56283
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.56766
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.57396
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.65189
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.68484
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.76629
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.72663
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.66184
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.67627
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.65491
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.61051
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.6293
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.61153
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.57274
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.57274
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.60747
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.57274
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.57274
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.57274
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.55236
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.568
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.57048
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.50547
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.53166
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.50579
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.47073
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.47073
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.54721
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.47722
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.47722
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.49152
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.49283
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.48634
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.48634
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.46686
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.39548
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.39813
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.36909
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.41487
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.38873
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.47684
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.48272
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.44359
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.437
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.43707
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.46313
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.48307
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.46313
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.48913
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.5436
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.53467
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.56481
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.56297
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.56297
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.56297
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.56942
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.56942
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.63895
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.60424
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.63895
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.56942
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.56942
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.57587
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.57587
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.57587
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.51771
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.53713
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.59995
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.58639
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.50088
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.52945
# No entry. Sleeping 5 secs...
# -----
# Entry Zscore: 0.52945
# No entry. Sleeping 5 secs...
# -----
