# %%
# main issues:
# fix stop loss/ max wdd
# partial fills
# multiple pairs at one time
# issues with multiple pairs with similar legs, memory management
# trailing profit take
#     1) take 
#     1) sell bad leg and use winning leg to run    

# innovations
# increase volume
# make new models whcih are scalping or momentum models

# kalmans filters
# copulas
# nonlinear distributions
# extreme value theory
# last three are similar
# pair trading with multiple exchanges

# limit orders
# max win drawdown
# advanced risk mitigation 
# if long and first priotirty to get rid off -> sell at market
# if short and first prioity to get rid off -> sell at market
# pair splitting

# %%
# imports and requirements
import json
import requests
import pandas as pd
import numpy as np
import ccxt
import time
import datetime as dt
import matplotlib.pyplot as plt

from binance.client import Client
from binance.enums import *

# %%
# init client
apiKey = 'Xo3vFSsM4XoYge93eqCA3gxmHQTN3rWqOs1LtUsHK9UQDKFcvRp1hMRmIiFIolsh'
apiSecret = ';)'

# python-binance init
client = Client(apiKey, apiSecret)
# ccxt init
exchange = ccxt.binance({
    'apiKey': 'Xo3vFSsM4XoYge93eqCA3gxmHQTN3rWqOs1LtUsHK9UQDKFcvRp1hMRmIiFIolsh',
    'secret': ';)',
    'enableRateLimit': True,  # as required by the Manual
    'options': { 'defaultType': 'future' }
})

# %%
# inputs
leg1 = input("Input leg 1: ")
leg2 = input("Input leg 2: ")
timeframe = input("Input timeframe/ interval: ")
emalen = input("Input Lookback/ EMA length: ")
legval = float(input("Leg Value: "))

# convert legs
if leg1 == 'ONTUSDT':
    newLeg1 = 'ONT/USDT'
    # prec = 1 dp, 4 price
elif leg1 == 'ETHUSDT':
    newLeg1 = 'ETH/USDT'
    # prec = 3 dp, 2 price
elif leg1 == 'BCHUSDT':
    newLeg1 = 'BCH/USDT'
    # prec = 3 dp, 2 price
elif leg1 == 'TRXUSDT':
    newleg1 = 'TRX/USDT'
    # prec = 0 dp, 5 price
    
if leg2 == 'QTUMUSDT':
    newLeg2 = 'QTUM/USDT'
    # prec = 1 dp, 3 price
elif leg2 == 'XTZUSDT':
    newLeg2 = 'XTZ/USDT'
    # prec = 1 dp, 3 price
elif leg2 == 'LTCUSDT':
    newLeg2 = 'LTC/USDT'
    # prec = 3 dp, 2 price
elif leg2 == 'BATUSDT':
    newLeg2 = 'BAT/USDT'
    # prec = 1 dp, 4 price

print("New leg 1:", format(newLeg1))
print("New leg 2:", format(newLeg2))
# Out:
# Input leg 1: BCHUSDT
# Input leg 2: LTCUSDT
# Input timeframe/ interval: 30m
# Input Lookback/ EMA length: 20
# Leg Value: 5
# New leg 1: BCH/USDT
# New leg 2: LTC/USDT

# %%
# create dataframe
def dataframe(symbol, interval, timeframe):
    rootUrl = 'https://api.binance.com/api/v1/klines'
    url = rootUrl + '?symbol=' + symbol + '&interval=' + interval + '&limit=' + timeframe
    data = json.loads(requests.get(url).text)
    df = pd.DataFrame(data)
    df.columns = ['open_time',
                 'o', 'h', 'l', 'c', 'v',
                 'closeTime', 'qav', 'numTrades',
                 'takerBase_Bol', 'takerQuoteVol', 'ignore']
    df.index = [dt.datetime.fromtimestamp(x/1000.0) for x in df.closeTime]
    return df

dataframe(leg1, timeframe, emalen)
# Out:
#                              open_time             o             h  \
def shortSide(leg1, leg2, legval):
    
    print("Short side function: ...")
    # amount for each leg
    priceLeg1 = dataframe(leg1,timeframe,emalen)['c'].astype('float')[-1].tolist()
    amountLeg1 = round(legval/priceLeg1,3)
    print ("Amount of leg1: {}". format(amountLeg1))
    
    priceLeg2 = dataframe(leg2,timeframe,emalen)['c'].astype('float')[-1].tolist()
    amountLeg2 = round(legval/priceLeg2,1)
    print ("Amount of leg2: {}". format(amountLeg2))
    print("-----")


    # short leg1    
    order1 = exchange.createOrder(newLeg1, 'market', 'sell', amountLeg1)
    print("Shorted leg 1")
    print(order1)
    # long leg 2
    order2 = exchange.createOrder(newLeg2, 'market', 'buy', amountLeg2)
    print("Longed leg 2")
    print(order2)
    
    inPos = True
    print ("inPos status before exit checks: {}". format(inPos))
    print("-----")

    
    # exit conds
    while (inPos == True):
        exZscore = currZscore()
            
        if exZscore <= 0:
            print ("Exiting! Current ZScore: {}". format(exZscore))
            order3 = exchange.createOrder (newLeg1, 'market', 'buy', amountLeg1)
            print("Long/ exited leg 1")
            print(order3)
            order4 = exchange.createOrder (newLeg2, 'market', 'sell', amountLeg2)
            print("Short/ exited leg 2")
            print(order4)
            print("-----")
            inPos = False
            print ("inPos status after exiting: {}". format(inPos))
        else:
            print ("Current ZScore: {}". format(exZscore))
            print("Sleeping 5 secs...")
            print("-----")
            time.sleep(5)
    
    "Calling entryConds for new buy session..."
    entryConds()

# %%
# long buy
def longSide(leg1, leg2, legval):
    
    print("Long side function: ...")
    # amount for each leg
    priceLeg1 = dataframe(leg1,timeframe,emalen)['c'].astype('float')[-1].tolist()
    amountLeg1 = round(legval/priceLeg1,3)
    print ("Amount of leg1: {}". format(amountLeg1))
    
    priceLeg2 = dataframe(leg2,timeframe,emalen)['c'].astype('float')[-1].tolist()
    amountLeg2 = round(legval/priceLeg2,1)
    print ("Amount of leg2: {}". format(amountLeg2))
    print("-----")
        
    # long leg1
    order1 = exchange.createOrder(newLeg1, 'market', 'buy', amountLeg1)
    print("Longed leg 1")
    print(order1)
    # short leg 2
    order2 = exchange.createOrder(newLeg2, 'market', 'sell', amountLeg2)
    print("Shorted leg 2")
    print(order2)
    print("-----")
    
    inPos = True
    print ("inPos status: {}". format(inPos))
    
    while (inPos == True):
        exZscore = currZscore()
            
        if exZscore >= 0:
            print ("Exiting! Current ZScore: {}". format(exZscore))
            order3 = exchange.createOrder (newLeg1, 'market', 'sell', amountLeg1)
            print("Short/ exited leg 1")
            print(order3)
            order4 = exchange.createOrder (newLeg2, 'market', 'buy', amountLeg2)
            print("Long/ exited leg 2")
            print(order4)
            print("-----")
            inPos = False
            print ("inPos status after exiting: {}". format(inPos))
        else:
            print ("Current ZScore: {}". format(exZscore))
            print("Sleeping 5 secs...")
            print("-----")
            time.sleep(5)
    
    "Calling entryConds"
    entryConds()

# %%
# entry conds
def entryConds():
    entered = False
    print ("Entry status at start of loop: {}". format(entered))
    print("-----")
    
    while entered == False:
        enZscore = currZscore()
        print ("Entry Zscore: {}". format(enZscore))

        if enZscore >= 2:
            print("Entering short side")
            print("-----")
            entered = True
            shortSide(leg1,leg2,legval)
        elif enZscore <= -2:
            print("Entering long side")
            print("-----")
            entered = True
            longSide(leg1,leg2,legval)
        else:
            print("No entry. Sleeping 5 secs...")
            print("-----")
            time.sleep(5)

entryConds()
# Out:
# Entry status at start of loop: False
# -----
# Entry Zscore: 2.62753
# Entering short side
# -----
# Short side function: ...
# Amount of leg1: 0.019
# Amount of leg2: 0.1
# -----
# Shorted leg 1
# {'info': {'orderId': 1217550129, 'symbol': 'BCHUSDT', 'status': 'NEW', 'clientOrderId': 'Xd73T7gb2JPQCONXHOucwP', 'price': '0', 'avgPrice': '0.00000', 'origQty': '0.019', 'executedQty': '0', 'cumQty': '0', 'cumQuote': '0', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'BOTH', 'stopPrice': '0', 'workingType': 'CONTRACT_PRICE', 'origType': 'MARKET', 'updateTime': 1591322553186}, 'id': '1217550129', 'clientOrderId': 'Xd73T7gb2JPQCONXHOucwP', 'timestamp': None, 'datetime': None, 'lastTradeTimestamp': None, 'symbol': 'BCH/USDT', 'type': 'market', 'side': 'sell', 'price': 0.0, 'amount': 0.019, 'cost': 0.0, 'average': None, 'filled': 0.0, 'remaining': 0.019, 'status': 'open', 'fee': None, 'trades': None}
# Longed leg 2
# {'info': {'orderId': 377097177, 'symbol': 'LTCUSDT', 'status': 'NEW', 'clientOrderId': 'cFQmEWFSGy2aw5SBkb2kR2', 'price': '0', 'avgPrice': '0.00000', 'origQty': '0.100', 'executedQty': '0', 'cumQty': '0', 'cumQuote': '0', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'BOTH', 'stopPrice': '0', 'workingType': 'CONTRACT_PRICE', 'origType': 'MARKET', 'updateTime': 1591322553690}, 'id': '377097177', 'clientOrderId': 'cFQmEWFSGy2aw5SBkb2kR2', 'timestamp': None, 'datetime': None, 'lastTradeTimestamp': None, 'symbol': 'LTC/USDT', 'type': 'market', 'side': 'buy', 'price': 0.0, 'amount': 0.1, 'cost': 0.0, 'average': None, 'filled': 0.0, 'remaining': 0.1, 'status': 'open', 'fee': None, 'trades': None}
# inPos status before exit checks: True
# -----
# Current ZScore: 2.64564
# Sleeping 5 secs...
# -----
# Current ZScore: 2.64951
# Sleeping 5 secs...
# -----
# Current ZScore: 2.57269
# Sleeping 5 secs...
# -----
# Current ZScore: 2.6612
# Sleeping 5 secs...
# -----
# Current ZScore: 2.68894
# Sleeping 5 secs...
# -----
# Current ZScore: 2.62636
# Sleeping 5 secs...
# -----
# Current ZScore: 2.61045
# Sleeping 5 secs...
# -----
# Current ZScore: 2.63818
# Sleeping 5 secs...
# -----
# Current ZScore: 2.63049
# Sleeping 5 secs...
# -----
# Current ZScore: 2.62065
# Sleeping 5 secs...
# -----
# Current ZScore: 2.65196
# Sleeping 5 secs...
# -----
# Current ZScore: 2.67888
# Sleeping 5 secs...
# -----
# Current ZScore: 2.69604
# Sleeping 5 secs...
# -----
# Current ZScore: 2.64843
# Sleeping 5 secs...
# -----
# Current ZScore: 2.6456
# Sleeping 5 secs...
# -----
# Current ZScore: 2.68461
# Sleeping 5 secs...
# -----
# Current ZScore: 2.61332
# Sleeping 5 secs...
# Sleeping 5 secs...
# -----
# Current ZScore: 2.45244
# Sleeping 5 secs...
# -----
# Current ZScore: 2.44326
# Sleeping 5 secs...
# -----
# Current ZScore: 2.46129
# Sleeping 5 secs...
# -----
# Current ZScore: 2.40509
# Sleeping 5 secs...
# -----
# Current ZScore: 2.48305
# Sleeping 5 secs...
# -----
# Current ZScore: 2.50555
# Sleeping 5 secs...
# -----
# Current ZScore: 2.46898
# Sleeping 5 secs...
# -----
# Current ZScore: 2.50761
# Sleeping 5 secs...
# -----
# Current ZScore: 2.55424
# Sleeping 5 secs...
# -----
# Current ZScore: 2.49665
# Sleeping 5 secs...
# -----
# Current ZScore: 2.53739
# Sleeping 5 secs...
# -----
# Current ZScore: 2.49457
# Sleeping 5 secs...
# -----
# Current ZScore: 2.51805
# Sleeping 5 secs...
# -----
# Current ZScore: 2.56347
# Sleeping 5 secs...
# -----
# Current ZScore: 2.51822
# Sleeping 5 secs...
# -----
# Current ZScore: 2.55809
# Sleeping 5 secs...
# -----
# Current ZScore: 2.62934
# Sleeping 5 secs...
# -----
# Current ZScore: 2.57034
# Sleeping 5 secs...
# -----
# Current ZScore: 2.62591
# Sleeping 5 secs...
# -----
# Current ZScore: 2.49902
# Sleeping 5 secs...
# -----
# Current ZScore: 2.52011
# Sleeping 5 secs...
# -----
# Current ZScore: 2.51805
# Sleeping 5 secs...
# -----
# Current ZScore: 2.50967
# Sleeping 5 secs...
# -----
# Current ZScore: 2.57853
# Sleeping 5 secs...
# -----
# Current ZScore: 2.56998
# Sleeping 5 secs...
# -----
# Current ZScore: 2.58656
# Sleeping 5 secs...
# -----
# Current ZScore: 2.56199
# Sleeping 5 secs...
# -----
# Current ZScore: 2.56411
# Sleeping 5 secs...
# -----
# Current ZScore: 2.54776
# Sleeping 5 secs...
# -----
# Current ZScore: 2.60468
# Sleeping 5 secs...
# -----
# Current ZScore: 2.60468
# Sleeping 5 secs...
# -----
# Current ZScore: 2.60468
# Sleeping 5 secs...
# -----
# Current ZScore: 2.60468
# Sleeping 5 secs...
# -----
# Current ZScore: 2.54614
# Sleeping 5 secs...
# -----
# Current ZScore: 2.54309
# Sleeping 5 secs...
# -----
# Current ZScore: 2.5903
# Sleeping 5 secs...
# -----
# Current ZScore: 2.58351
# Sleeping 5 secs...
# -----
# Current ZScore: 2.60036
# Sleeping 5 secs...
# -----
# Current ZScore: 2.60036
# Sleeping 5 secs...
# -----
# Current ZScore: 2.51365
# Sleeping 5 secs...
# -----
# Current ZScore: 2.51365
# Sleeping 5 secs...
# -----
# Current ZScore: 2.51758
# Sleeping 5 secs...
# -----
# Current ZScore: 2.50081
# Sleeping 5 secs...
# -----
# Current ZScore: 2.52844
# Sleeping 5 secs...
# -----
# Current ZScore: 2.45934
# Sleeping 5 secs...
# -----
# Current ZScore: 2.50288
# Sleeping 5 secs...
# -----
# Current ZScore: 2.49873
# Sleeping 5 secs...
# -----
# Current ZScore: 2.5268
# Sleeping 5 secs...
# -----
# Current ZScore: 2.52639
# Sleeping 5 secs...
# -----
# Current ZScore: 2.52639
# Sleeping 5 secs...
# -----
# -----
# Current ZScore: 2.30434
# Sleeping 5 secs...
# -----
# Current ZScore: 2.41182
# Sleeping 5 secs...
# -----
# Current ZScore: 2.40921
# Sleeping 5 secs...
# -----
# Current ZScore: 2.32824
# Sleeping 5 secs...
# -----
# Current ZScore: 2.22533
# Sleeping 5 secs...
# -----
# Current ZScore: 2.248
# Sleeping 5 secs...
# -----
# Current ZScore: 2.24001
# Sleeping 5 secs...
# -----
# Current ZScore: 2.27244
# Sleeping 5 secs...
# -----
# Current ZScore: 2.2704
# Sleeping 5 secs...
# -----
# Current ZScore: 2.28021
# Sleeping 5 secs...
# -----
# Current ZScore: 2.26976
# Sleeping 5 secs...
# -----
# Current ZScore: 2.2199
# Sleeping 5 secs...
# -----
# Current ZScore: 2.24331
# Sleeping 5 secs...
# -----
# Current ZScore: 2.23832
# Sleeping 5 secs...
# -----
# Current ZScore: 2.24599
# Sleeping 5 secs...
# -----
# Current ZScore: 2.27193
# Sleeping 5 secs...
# -----
# Current ZScore: 2.28766
# Sleeping 5 secs...
# -----
# Current ZScore: 2.2979
# Sleeping 5 secs...
# -----
# Current ZScore: 2.33622
# Sleeping 5 secs...
# -----
# Current ZScore: 2.25525
# Sleeping 5 secs...
# -----
# Current ZScore: 2.28563
# Sleeping 5 secs...
# -----
# Current ZScore: 2.29535
# Sleeping 5 secs...
# -----
# Current ZScore: 2.37209
# Sleeping 5 secs...
# -----
# Current ZScore: 2.30045
# Sleeping 5 secs...
# -----
# Current ZScore: 2.32671
# Sleeping 5 secs...
# -----
# Current ZScore: 2.29764
# Sleeping 5 secs...
# -----
# Current ZScore: 2.28306
# Sleeping 5 secs...
# -----
# Current ZScore: 2.10645
# Sleeping 5 secs...
# -----
# Current ZScore: 2.12859
# Sleeping 5 secs...
# -----
# Current ZScore: 2.04364
# Sleeping 5 secs...
# -----
# Current ZScore: 2.08463
# Sleeping 5 secs...
# -----
# Current ZScore: 2.10572
# Sleeping 5 secs...
# -----
# Current ZScore: 2.06923
# Sleeping 5 secs...
# -----
# Current ZScore: 2.07053
# Sleeping 5 secs...
# -----
# Current ZScore: 1.97888
# Sleeping 5 secs...
# -----
# Current ZScore: 2.04756
# Sleeping 5 secs...
# -----
# Current ZScore: 2.08925
# Sleeping 5 secs...
# -----
# Current ZScore: 2.1266
# Sleeping 5 secs...
# -----
# Current ZScore: 2.26664
# Sleeping 5 secs...
# -----
# Current ZScore: 2.11164
# Sleeping 5 secs...
# -----
# Current ZScore: 2.21268
# Sleeping 5 secs...
# -----
# Current ZScore: 2.1379
# Sleeping 5 secs...
# -----
# Current ZScore: 1.9504
# Sleeping 5 secs...
# -----
# Current ZScore: 2.0684
# Sleeping 5 secs...
# -----
# Current ZScore: 2.08463
# Sleeping 5 secs...
# -----
# Current ZScore: 2.12203
# Sleeping 5 secs...
# -----
# Current ZScore: 2.12203
# Sleeping 5 secs...
# -----
# Current ZScore: 2.10336
# Sleeping 5 secs...
# -----
# Current ZScore: 2.07383
# Sleeping 5 secs...
# -----
# Current ZScore: 2.07383
# Sleeping 5 secs...
# -----
# Current ZScore: 2.07383
# Sleeping 5 secs...
# -----
# Current ZScore: 2.08463
# Sleeping 5 secs...
# -----
# Current ZScore: 2.1192
# Sleeping 5 secs...
# -----
# Current ZScore: 2.07858
# Sleeping 5 secs...
# -----
# Current ZScore: 2.1192
# Sleeping 5 secs...
# -----
# Current ZScore: 2.21247
# Sleeping 5 secs...
# -----
# Current ZScore: 2.10074
# Sleeping 5 secs...
# -----
# Current ZScore: 2.11352
# Sleeping 5 secs...
# -----
# Current ZScore: 2.09251
# Sleeping 5 secs...
# -----
# Current ZScore: 2.11993
# Sleeping 5 secs...
# -----
# Current ZScore: 2.19856
# Sleeping 5 secs...
# -----
# Current ZScore: 2.17755
# Sleeping 5 secs...
# -----
# Current ZScore: 2.07131
# Sleeping 5 secs...
# -----
# Current ZScore: 2.13014
# Sleeping 5 secs...
# -----
# Current ZScore: 2.06833
# Sleeping 5 secs...
# -----
# Current ZScore: 2.07279
# Sleeping 5 secs...
# -----
# Current ZScore: 2.11178
# Sleeping 5 secs...
# -----
# Current ZScore: 2.17466
# Sleeping 5 secs...
# -----
# Current ZScore: 2.17466
# Sleeping 5 secs...
# -----
# Current ZScore: 1.99262
# Sleeping 5 secs...
# -----
# Current ZScore: 2.1036
# Sleeping 5 secs...
# -----
# Current ZScore: 2.10397
# Sleeping 5 secs...
# -----
# Current ZScore: 2.06337
# Sleeping 5 secs...
# -----
# Current ZScore: 2.04491
# Sleeping 5 secs...
# -----
# Current ZScore: 2.05954
# Sleeping 5 secs...
# -----
# Current ZScore: 2.06628
# Sleeping 5 secs...
# -----
# Current ZScore: 2.16286
# Sleeping 5 secs...
# -----
# Current ZScore: 2.03388
# Sleeping 5 secs...
# -----
# Current ZScore: 2.13223
# Sleeping 5 secs...
# -----
# Current ZScore: 2.13049
# Sleeping 5 secs...
# -----
# Current ZScore: 2.08001
# Sleeping 5 secs...
# -----
# Current ZScore: 2.13576
# Sleeping 5 secs...
# -----
# Current ZScore: 2.10682
# Sleeping 5 secs...
# -----
# Current ZScore: 2.04666
# Sleeping 5 secs...
# -----
# Current ZScore: 2.07147
# Sleeping 5 secs...
# -----
# Current ZScore: 2.06124
# Sleeping 5 secs...
# -----
# Current ZScore: 2.03938
# Sleeping 5 secs...
# -----
# Current ZScore: 2.16368
# Sleeping 5 secs...
# -----
# Current ZScore: 2.24079
# Sleeping 5 secs...
# -----
# Current ZScore: 1.81548
# Sleeping 5 secs...
# -----
# Current ZScore: 1.88197
# Sleeping 5 secs...
# -----
# Current ZScore: 1.84791
# Sleeping 5 secs...
# -----
# Current ZScore: 1.83214
# Sleeping 5 secs...
# -----
# Current ZScore: 1.88405
# Sleeping 5 secs...
# -----
# Current ZScore: 1.88276
# Sleeping 5 secs...
# -----
# Current ZScore: 1.93033
# Sleeping 5 secs...
# -----
# Current ZScore: 2.01953
# Sleeping 5 secs...
# -----
# Current ZScore: 2.01811
# Sleeping 5 secs...
# -----
# Current ZScore: 2.01332
# Sleeping 5 secs...
# -----
# Current ZScore: 2.06525
# Sleeping 5 secs...
# -----
# Current ZScore: 1.98437
# Sleeping 5 secs...
# -----
# Current ZScore: 1.99406
# Sleeping 5 secs...
# -----
# Current ZScore: 2.06546
# Sleeping 5 secs...
# -----
# Current ZScore: 1.98274
# Sleeping 5 secs...
# -----
# Current ZScore: 2.00298
# Sleeping 5 secs...
# -----
# Current ZScore: 2.02969
# Sleeping 5 secs...
# -----
# Current ZScore: 1.95179
# Sleeping 5 secs...
# -----
# Current ZScore: 1.97695
# Sleeping 5 secs...
# -----
# Current ZScore: 1.96719
# Sleeping 5 secs...
# -----
# Current ZScore: 1.86505
# Sleeping 5 secs...
# -----
# Current ZScore: 1.86023
# Sleeping 5 secs...
# -----
# Current ZScore: 1.88798
# Sleeping 5 secs...
# -----
# Current ZScore: 1.93561
# Sleeping 5 secs...
# -----
# Current ZScore: 1.89835
# Sleeping 5 secs...
# -----
# Current ZScore: 1.92569
# Sleeping 5 secs...
# -----
# Current ZScore: 1.89096
# Sleeping 5 secs...
# -----
# Current ZScore: 1.87773
# Sleeping 5 secs...
# -----
# Current ZScore: 1.9455
# Sleeping 5 secs...
# -----
# Current ZScore: 1.90278
# Sleeping 5 secs...
# -----
# Current ZScore: 1.96693
# Sleeping 5 secs...
# -----
# Current ZScore: 1.98156
# Sleeping 5 secs...
# -----
# Current ZScore: 1.98156
# Sleeping 5 secs...
# -----
# Current ZScore: 1.98156
# Sleeping 5 secs...
# -----
# Current ZScore: 1.93506
# Sleeping 5 secs...
# -----
# Current ZScore: 1.93193
# Sleeping 5 secs...
# -----
# Current ZScore: 2.08482
# Sleeping 5 secs...
# -----
# Current ZScore: 1.93017
# Sleeping 5 secs...
# -----
# Current ZScore: 1.94988
# Sleeping 5 secs...
# -----
# Current ZScore: 1.93009
# Sleeping 5 secs...
# -----
# Current ZScore: 1.93009
# Sleeping 5 secs...
# -----
# Current ZScore: 1.96414
# Sleeping 5 secs...
# -----
# Current ZScore: 1.90071
# Sleeping 5 secs...
# -----
# Current ZScore: 1.91338
# Sleeping 5 secs...
# -----
# Current ZScore: 1.97439
# Sleeping 5 secs...
# -----
# Current ZScore: 1.97926
# Sleeping 5 secs...
# -----
# Current ZScore: 2.00575
# Sleeping 5 secs...
# -----
# Current ZScore: 2.00599
# Sleeping 5 secs...
# -----
# Current ZScore: 1.99356
# Sleeping 5 secs...
# -----
# Current ZScore: 1.96977
# Sleeping 5 secs...
# -----
# Current ZScore: 1.97464
# Sleeping 5 secs...
# -----
# Current ZScore: 2.00118
# Sleeping 5 secs...
# -----
# Current ZScore: 1.97695
# Sleeping 5 secs...
# -----
# Current ZScore: 1.98642
# Sleeping 5 secs...
# -----
# Current ZScore: 1.99611
# Sleeping 5 secs...
# -----
# Current ZScore: 2.04619
# Sleeping 5 secs...
# -----
# Current ZScore: 2.03898
# Sleeping 5 secs...
# -----
# Current ZScore: 2.03898
# Sleeping 5 secs...
# -----
# Current ZScore: 2.04695
# Sleeping 5 secs...
# -----
# Current ZScore: 2.00828
# Sleeping 5 secs...
# -----
# Current ZScore: 1.94409
# Sleeping 5 secs...
# -----
# Current ZScore: 2.01056
# Sleeping 5 secs...
# -----
# Current ZScore: 2.0736
# Sleeping 5 secs...
# -----
# Current ZScore: 1.92905
# Sleeping 5 secs...
# -----
# Current ZScore: 1.94151
# Sleeping 5 secs...
# -----
# Current ZScore: 1.86274
# Sleeping 5 secs...
# -----
# Current ZScore: 1.96588
# Sleeping 5 secs...
# -----
# Current ZScore: 1.92156
# Sleeping 5 secs...
# -----
# Current ZScore: 1.97797
# Sleeping 5 secs...
# -----
# Current ZScore: 2.00936
# Sleeping 5 secs...
# -----
# Current ZScore: 1.92619
# Sleeping 5 secs...
# -----
# Current ZScore: 1.91105
# Sleeping 5 secs...
# -----
# Current ZScore: 1.87459
# Sleeping 5 secs...
# -----
# Current ZScore: 1.91905
# Sleeping 5 secs...
# -----
# Current ZScore: 1.9389
# Sleeping 5 secs...
# -----
# Current ZScore: 1.90839
# Sleeping 5 secs...
# -----
# Current ZScore: 1.95811
# Sleeping 5 secs...
# -----
# Current ZScore: 1.90632
# Sleeping 5 secs...
# -----
# Current ZScore: 1.91105
# Sleeping 5 secs...
# -----
# Current ZScore: 1.90722
# Sleeping 5 secs...
# -----
# Current ZScore: 1.85046
# Sleeping 5 secs...
# -----
# Current ZScore: 1.92312
# Sleeping 5 secs...
# -----
# Current ZScore: 1.87575
# Sleeping 5 secs...
# -----
# Current ZScore: 1.83264
# Sleeping 5 secs...
# -----
# Current ZScore: 1.89026
# Sleeping 5 secs...
# -----
# Current ZScore: 1.75349
# Sleeping 5 secs...
# -----
# Current ZScore: 1.75858
# Sleeping 5 secs...
# -----
# Current ZScore: 1.82157
# Sleeping 5 secs...
# -----
# Current ZScore: 1.85013
# Sleeping 5 secs...
# -----
# Current ZScore: 1.90573
# Sleeping 5 secs...
# -----
# Current ZScore: 1.89298
# Sleeping 5 secs...
# -----
# Current ZScore: 1.92312
# Sleeping 5 secs...
# -----
# Current ZScore: 1.8733
# Sleeping 5 secs...
# -----
# Current ZScore: 1.96716
# Sleeping 5 secs...
# -----
# Current ZScore: 1.94461
# Sleeping 5 secs...
# -----
# Current ZScore: 2.06967
# Sleeping 5 secs...
# -----
# Current ZScore: 1.97283
# Sleeping 5 secs...
# -----
# Current ZScore: 1.94591
# Sleeping 5 secs...
# -----
# Current ZScore: 1.89565
# Sleeping 5 secs...
# -----
# Current ZScore: 1.8357
# Sleeping 5 secs...
# -----
# Current ZScore: 1.97014
# Sleeping 5 secs...
# -----
# Current ZScore: 1.85559
# Sleeping 5 secs...
# -----
# Current ZScore: 1.90036
# Sleeping 5 secs...
# -----
# Current ZScore: 1.83147
# Sleeping 5 secs...
# -----
# Current ZScore: 1.87839
# Sleeping 5 secs...
# -----
# Current ZScore: 1.85286
# Sleeping 5 secs...
# -----
# Current ZScore: 1.81245
# Sleeping 5 secs...
# -----
# Current ZScore: 1.876
# Sleeping 5 secs...
# -----
# Current ZScore: 1.91588
# Sleeping 5 secs...
# -----
# Current ZScore: 1.90632
# Sleeping 5 secs...
# -----
# Current ZScore: 1.92106
# Sleeping 5 secs...
# -----
# Current ZScore: 1.92106
# Sleeping 5 secs...
# -----
# Current ZScore: 1.92077
# Sleeping 5 secs...
# -----
# Current ZScore: 1.83933
# Sleeping 5 secs...
# -----
# Current ZScore: 1.84258
# Sleeping 5 secs...
# -----
# Current ZScore: 1.85559
# Sleeping 5 secs...
# -----
# Current ZScore: 1.85516
# Sleeping 5 secs...
# -----
# Current ZScore: 1.82535
# Sleeping 5 secs...
# -----
# Current ZScore: 1.80619
# Sleeping 5 secs...
# -----
# Current ZScore: 1.81255
# Sleeping 5 secs...
# -----
# Current ZScore: 1.92398
# Sleeping 5 secs...
# -----
# Current ZScore: 1.97345
# Sleeping 5 secs...
# -----
# Current ZScore: 1.90927
# Sleeping 5 secs...
# -----
# Current ZScore: 1.9698
# Sleeping 5 secs...
# -----
# Current ZScore: 1.90927
# Sleeping 5 secs...
# -----
# Current ZScore: 1.83294
# Sleeping 5 secs...
# -----
# Current ZScore: 1.94412
# Sleeping 5 secs...
# -----
# Current ZScore: 1.85144
# Sleeping 5 secs...
# -----
# Current ZScore: 1.87185
# Sleeping 5 secs...
# -----
# Current ZScore: 1.92655
# Sleeping 5 secs...
# -----
# Current ZScore: 1.96409
# Sleeping 5 secs...
# -----
# Current ZScore: 1.95686
# Sleeping 5 secs...
# -----
# Current ZScore: 1.84204
# Sleeping 5 secs...
# -----
# Current ZScore: 2.0002
# Sleeping 5 secs...
# -----
# Current ZScore: 1.9269
# Sleeping 5 secs...
# -----
# Current ZScore: 1.97592
# Sleeping 5 secs...
# -----
# Current ZScore: 1.9222
# Sleeping 5 secs...
# -----
# Current ZScore: 1.93833
# Sleeping 5 secs...
# -----
# Current ZScore: 1.93159
# Sleeping 5 secs...
# -----
# Current ZScore: 1.9448
# Sleeping 5 secs...
# -----
# Current ZScore: 1.96614
# Sleeping 5 secs...
# -----
# Current ZScore: 1.92125
# Sleeping 5 secs...
# -----
# Current ZScore: 1.93159
# Sleeping 5 secs...
# -----
# Current ZScore: 1.9524
# Sleeping 5 secs...
# -----
# Current ZScore: 1.91774
# Sleeping 5 secs...
# -----
# Current ZScore: 1.91163
# Sleeping 5 secs...
# -----
# Current ZScore: 1.9389
# Sleeping 5 secs...
# -----
# Current ZScore: 1.9389
# Sleeping 5 secs...
# -----
# Current ZScore: 1.92896
# Sleeping 5 secs...
# -----
# Current ZScore: 1.85319
# Sleeping 5 secs...
# -----
# Current ZScore: 1.8399
# Sleeping 5 secs...
# -----
# Current ZScore: 1.80942
# Sleeping 5 secs...
# -----
# Current ZScore: 1.82225
# Sleeping 5 secs...
# -----
# Current ZScore: 1.78043
# Sleeping 5 secs...
# -----
# Current ZScore: 1.76988
# Sleeping 5 secs...
# -----
# Current ZScore: 1.80664
# Sleeping 5 secs...
# -----
# Current ZScore: 1.80908
# Sleeping 5 secs...
# -----
# Current ZScore: 1.77605
# Sleeping 5 secs...
# -----
# Current ZScore: 1.78043
# Sleeping 5 secs...
# -----
# Current ZScore: 1.80091
# Sleeping 5 secs...
# -----
# Current ZScore: 1.75151
# Sleeping 5 secs...
# -----
# Current ZScore: 1.80748
# Sleeping 5 secs...
# -----
# Current ZScore: 1.86105
# Sleeping 5 secs...
# -----
# Current ZScore: 1.82225
# Sleeping 5 secs...
# -----
# Current ZScore: 1.79095
# Sleeping 5 secs...
# -----
# Current ZScore: 1.79095
# Sleeping 5 secs...
# -----
# Current ZScore: 1.80142
# Sleeping 5 secs...
# -----
# Current ZScore: 1.81948
# Sleeping 5 secs...
# -----
# Current ZScore: 1.85166
# Sleeping 5 secs...
# -----
# Current ZScore: 1.89625
# Sleeping 5 secs...
# -----
# Current ZScore: 1.87091
# Sleeping 5 secs...
# -----
# Current ZScore: 1.89151
# Sleeping 5 secs...
# -----
# Current ZScore: 1.94385
# Sleeping 5 secs...
# -----
# Current ZScore: 1.94385
# Sleeping 5 secs...
# -----
# Current ZScore: 1.91899
# Sleeping 5 secs...
# -----
# Current ZScore: 2.03238
# Sleeping 5 secs...
# -----
# Current ZScore: 2.01693
# Sleeping 5 secs...
# -----
# Current ZScore: 1.98591
# Sleeping 5 secs...
# -----
# Current ZScore: 1.98591
# Sleeping 5 secs...
# -----
# Current ZScore: 1.9915
# Sleeping 5 secs...
# -----
# Current ZScore: 1.96177
# Sleeping 5 secs...
# -----
# Current ZScore: 2.0174
# Sleeping 5 secs...
# -----
# Current ZScore: 1.96435
# Sleeping 5 secs...
# -----
# Current ZScore: 1.98131
# Sleeping 5 secs...
# -----
# Current ZScore: 2.0693
# Sleeping 5 secs...
# -----
# Current ZScore: 2.12337
# Sleeping 5 secs...
# -----
# Current ZScore: 2.09724
# Sleeping 5 secs...
# -----
# Current ZScore: 2.05087
# Sleeping 5 secs...
# -----
# Current ZScore: 2.05048
# Sleeping 5 secs...
# -----
# Current ZScore: 2.05048
# Sleeping 5 secs...
# -----
# Current ZScore: 2.06217
# Sleeping 5 secs...
# -----
# Current ZScore: 2.04079
# Sleeping 5 secs...
# -----
# Current ZScore: 2.03802
# Sleeping 5 secs...
# -----
# Current ZScore: 1.98662
# Sleeping 5 secs...
# -----
# Current ZScore: 1.99027
# Sleeping 5 secs...
# -----
# Current ZScore: 2.03496
# Sleeping 5 secs...
# -----
# Current ZScore: 2.00028
# Sleeping 5 secs...
# -----
# Current ZScore: 1.99282
# Sleeping 5 secs...
# -----
# Current ZScore: 2.0301
# Sleeping 5 secs...
# -----
# Current ZScore: 2.01441
# Sleeping 5 secs...
# -----
# Current ZScore: 2.02854
# Sleeping 5 secs...
# -----
# Current ZScore: 1.95313
# Sleeping 5 secs...
# -----
# Current ZScore: 1.98098
# Sleeping 5 secs...
# -----
# Current ZScore: 1.96303
# Sleeping 5 secs...
# -----
# Current ZScore: 2.01165
# Sleeping 5 secs...
# -----
# Current ZScore: 2.06622
# Sleeping 5 secs...
# -----
# Current ZScore: 2.00621
# Sleeping 5 secs...
# -----
# Current ZScore: 2.00429
# Sleeping 5 secs...
# -----
# Current ZScore: 1.97025
# Sleeping 5 secs...
# -----
# Current ZScore: 1.9625
# Sleeping 5 secs...
# -----
# Current ZScore: 2.00795
# Sleeping 5 secs...
# -----
# Current ZScore: 2.02534
# Sleeping 5 secs...
# -----
# Current ZScore: 1.99642
# Sleeping 5 secs...
# -----
# Current ZScore: 1.96973
# Sleeping 5 secs...
# -----
# Current ZScore: 1.9108
# Sleeping 5 secs...
# -----
